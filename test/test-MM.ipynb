# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import set_matplotlib_formats, display, Image 
set_matplotlib_formats('png', 'pdf')
# %matplotlib notebook

from culture import Culture, Simulation

# %%
c1 = Culture(25, 1, 5, 6, 100000)
c1.plot_net()
c1.plot_gsnet()

# %%
# %%time
pr = 50
c1.simulate(save_progress=pr)
c1.analyze()

for i in range(int(c1.usediter/pr)):
    print(i*pr)
    print(f'{i*pr} iterací')
    i = Image(filename=f'sim1_{i*pr}.png'); display(i)
# Out:
# Počet agentů: 25 (f:5, t:6)
# Počet všech propojení: 80
# Počet propojení která mohou interagovat (0 < similarity < 1): 0
# Počet komponent/kultur: 1
#
# Maximální počet iterací: 100000
# Model konvergoval v 2505 iteracích
#
#
# 0
# 0 iterací
# 50
# 50 iterací
# 100
# 100 iterací
# 150
# 150 iterací
# 200
# 200 iterací
# 250
# 250 iterací
# 300
# 300 iterací
# 350
# 350 iterací
# 400
# 400 iterací
# 450
# 450 iterací
# 500
# 500 iterací
# 550
# 550 iterací
# 600
# 600 iterací
# 650
# 650 iterací
# 700
# 700 iterací
# 750
# 750 iterací
# 800
# 800 iterací
# 850
# 850 iterací
# 900
# 900 iterací
# 950
# 950 iterací
# 1000
# 1000 iterací
# 1050
# 1050 iterací
# 1100
# 1100 iterací
# 1150
# 1150 iterací
# 1200
# 1200 iterací
# 1250
# 1250 iterací
# 1300
# 1300 iterací
# 1350
# 1350 iterací
# 1400
# 1400 iterací
# 1450
# 1450 iterací
# 1500
# 1500 iterací
# 1550
# 1550 iterací
# 1600
# 1600 iterací
# 1650
# 1650 iterací
# 1700
# 1700 iterací
# 1750
# 1750 iterací
# 1800
# 1800 iterací
# ...
